# %% [markdown]
# ## Make plot to compare models

# %%
import seaborn as sns
import pandas as pd

# %%
rmse_score = {
    'Linear' : 3.6,
    'Ridge' : 3.7,
    'Lasso' : 3.6,
    'KNN' : 2.5,
    'SVM' : 4.1,
    'XGBoost' : 1.9,
    'CatBoost' : 1.6
}

# %%
df = pd.DataFrame(rmse_score.items(), columns=['Model', 'RMSE'])

# %%
ax = sns.barplot(data=df.sort_values(by='RMSE', ascending=False), x='Model', y='RMSE')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '4.1'),
#  Text(0, 0, '3.7'),
#  Text(0, 0, '3.6'),
#  Text(0, 0, '3.6'),
#  Text(0, 0, '2.5'),
#  Text(0, 0, '1.9'),
#  Text(0, 0, '1.6')]
